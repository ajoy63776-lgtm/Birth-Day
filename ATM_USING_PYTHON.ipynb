# %% [markdown]
# <a href="https://colab.research.google.com/github/ajoy63776-lgtm/Birth-Day/blob/main/ATM_USING_PYTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class atm:
  def __init__(self) -> None:
    self.pin=''
    self.balance=0
    print("Welcome to the ATM")
    self.menu()
  def menu(self):
    put_input=  input("""
    1. Press 1 for create Your pin:
    2. Press 2 for Check Your Current Balance amoutnt:
    3. Press 3 for change Your pin_number:
    4. Press 4 for withdrew Money:
    5. press 5 for exit from ATM:
    6. Press 6 for close the process:

    """)

    if put_input=='1':
      self.create_pin()

    elif put_input=='2':
      self.check_balance()

    elif put_input=='3':
      self.change_pin()

    elif put_input=='4':
      self.WithdresMoney()

    elif put_input=='5':
      self.exitAtm()
    elif put_input=='6':
      self.closeprocess()

    else:
      print("Invalid Choice ")
      self.menu()

  def check_balance(self):
    User_pin=input("Enter Your Pin:")
    if User_pin==self.pin:
      print("Thank You")
      print("Your Balance is:",self.balance)
      self.menu()
    else:
      print("Incorrect Pin, Try Again")
      self.menu()

  def change_pin(self):
    old_pin= input("Enter your old pin Number:")

    if old_pin==self.pin:
      print("Thank You")
      NewPin=input("Enter your new pin:")
      self.pin=NewPin
      print("pin change succesfully and your new pin is:",self.pin)
      self.menu()
    else:
      print("Invalid Pin,Try Again")
      self.menu()

  def WithdresMoney(self):

    Amount_Money=int(input("Enter Money for WithDrew"))
    if Amount_Money>self.balance:
      print("Insufficient Balance")
    else:
      self.balance=self.balance-Amount_Money

      print("Your Rest Amount is Avalable :",self.balance)
      # print("Thank You ")
      self.menu()
    # print("Thank Yoy")
    # self.menu()

  def exitAtm(self):
    print("Thank You for Visiting")
    self.menu()

  def create_pin(self):
    user_pin=input("Enter a 4 digit number for  your pin for Creation")
    self.pin=user_pin
    print("pin creation successful and your pin is :", self.pin)
    user_balance=int(input("Enter your balance for diposite"))
    self.balance= user_balance
    print("total balance is ", self.balance)
    self.menu()

  def closeprocess(self):
    print("Thank You BYE BYE")

# %%
obj=atm()
# Out:
# Welcome to the ATM
#
#     1. Press 1 for create Your pin:
#     2. Press 2 for Check Your Current Balance amoutnt:
#     3. Press 3 for change Your pin_number:
#     4. Press 4 for withdrew Money:
#     5. press 5 for exit from ATM:
#     6. Press 6 for close the process:
#
#     1
# Enter a 4 digit number for  your pin for Creation1234
# pin creation successful and your pin is : 1234
# Enter your balance for diposite2
# total balance is  2
#
#     1. Press 1 for create Your pin:
#     2. Press 2 for Check Your Current Balance amoutnt:
#     3. Press 3 for change Your pin_number:
#     4. Press 4 for withdrew Money:
#     5. press 5 for exit from ATM:
#     6. Press 6 for close the process:
#
#     2
# Enter Your Pin:1234
# Thank You
# Your Balance is: 2
#
#     1. Press 1 for create Your pin:
#     2. Press 2 for Check Your Current Balance amoutnt:
#     3. Press 3 for change Your pin_number:
#     4. Press 4 for withdrew Money:
#     5. press 5 for exit from ATM:
# ...
